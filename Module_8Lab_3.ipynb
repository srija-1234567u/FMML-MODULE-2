# %% [markdown]
# <a href="https://colab.research.google.com/github/srija-1234567u/FMML-MODULE-2/blob/main/Module_8Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-07 16:58:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   183MB/s    in 0.4s
#
# 2022-06-07 16:58:47 (183 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23052  1802.08167v1  We present the Causal Gaussian Process Convolu...  stat
# 6515   1703.00039v1  We present an asymptotic criterion to determin...  stat
# 6393   1701.01293v2  OpenML is an online machine learning platform ...  stat
# 22258  1510.06779v3  We present tree- and list- structured density ...  stat
# 33885  1803.04509v1  We study sorting of permutations by random swa...    cs
# ...             ...                                                ...   ...
# 31496  1803.05536v1  This paper investigates the evaluation of dens...    cs
# 13969  1702.03389v2  Increasing nature-inspired metaheuristic algor...    cs
# 14234  1604.02634v2  We propose a unified and systematic framework ...  stat
# 24594   1409.1484v3  The emergence of new wearable technologies suc...    cs
# 31792   1005.0027v2  We propose a novel problem formulation of lear...    cs
#
#                                                    title  year  \
# 23052  Learning Causally-Generated Stationary Time Se...  2018
# 6515   A description length approach to determining t...  2017
# 6393   OpenML: An R Package to Connect to the Machine...  2017
# 22258  Cascaded High Dimensional Histograms: A Genera...  2015
# 33885            Sorting by Swaps with Noisy Comparisons  2018
# ...                                                  ...   ...
# 31496  Evaluation of Dense 3D Reconstruction from 2D ...  2018
# 13969    Whale swarm algorithm for function optimization  2017
# 14234  Online Nonnegative Matrix Factorization with O...  2016
# 24594  The Evolution of First Person Vision Methods: ...  2014
# 31792                    Learning from Multiple Outlooks  2010
#
#                                                 keywords
# 23052  [convolution, nonparametric, spectrally, dynam...
# 6515   [asymptotic, criterion, determine, compression...
# 6393   [researchers, experiments, collaborate, effici...
# 22258  [structured, estimation, dimensional, binaryca...
# 33885  [permutations, comparison, probability, protot...
# ...                                                  ...
# 31496  [investigates, evaluation, reconstruction, com...
# 13969  [increasing, metaheuristic, algorithms, optimi...
# 14234  [systematic, framework, performing, nonnegativ...
# 24594  [emergence, technologies, increased, scientist...
# 31792  [formulation, different, unlabeled, objective,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23052    [convolution, nonparametric, spectrally, dynam...
# 6515     [asymptotic, criterion, determine, compression...
# 6393     [researchers, experiments, collaborate, effici...
# 22258    [structured, estimation, dimensional, binaryca...
# 33885    [permutations, comparison, probability, protot...
#                                ...
# 10733    [optimization, consisting, iteratively, minimi...
# 21965    [typically, boltzmann, connections, resulting,...
# 30474    [algorithms, representations, unsupervised, su...
# 7252     [motivation, challenge, development, computati...
# 32108    [attracted, considerable, attention, algorithm...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8948 words.
# Out of those 4549 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="46870a50-a1bb-4ca2-9f68-6dcc288f1158" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46870a50-a1bb-4ca2-9f68-6dcc288f1158")) {                    Plotly.newPlot(                        "46870a50-a1bb-4ca2-9f68-6dcc288f1158",                        [{"x":["convolution","inference","variational","statistical","spectrally","generative","stationary","equivalent","contributions","dynamical","generated","synthetic","nonparametric","demonstrated","construction","inferential","phenomena","modelling","significantly","determining","asymptotic","reduction","criterion","principled","description","different","properties","dimension","observation","reasonable","suitability","underlying","examining","neuroimaging","empirical","numerical","clustering","compression","minimizes","hierarchical","structure","estimated","dimensionality","determine","dependency","furthermore","collaborate","researchers","visibility","reproducibility","facilitates","experiments","collaboration","increases","efficiently","illustrate","combination","interface","approaches","estimation","dimensions","histograms","analogies","estimates","histogram","visualized","generalization","structured","dimensional","optimization","permutations","intermediate","convergence","heuristics","experimental","distribution","theoretical","prototype","approximates","comparisons","randomized","comparison","probability","behaviour","recognition","character","difficult","algorithms","information","classification","improvement","capabilities","classifiers","incremental","algorithm","classifier","available","benchmark","forgetting","retrained","catastrophic","respectively","successfully","computing","marginalization","classifying","validation","presented","iteratively","hyperspectral","maximizes","processing","efficient","implementation","nonlinear","extracted","selection","dependence","therefore","independence","functions","dependent","appropriate","assumption","integrate","aggregating","interacting","traversal","extraction","specialized","manipulating","seamlessly","biological","relational","integrated","predictions","performed","computational","unstructured","particular","heterogeneous","framework","knowledge","constructing","demonstrate","consisting","facilitate","components","representation","declarative","projections","traditional","accelerated","variables","projection","approximately","massively","computation","distances","prohibitive","designated","segmentation","especially","commercial","commercially","implicitly","sometimes","considering","requirements","represents","addressed","developed","continuous","nonconvex","minimization","important","stochastic","practical","additional","machinery","increasingly","corresponds","regularized","minimizing","introduce","solutions","extensive","randomness","programming","inefficient","implement","iterations","heuristic","associated","paradigms","optimizations","comparatively","experiences","exploitation","providers"],"y":[47,205,50,168,1,126,20,63,49,20,190,111,21,110,54,1,32,44,248,44,16,106,48,16,62,741,217,76,66,35,10,129,15,4,165,68,142,30,25,107,360,67,51,88,42,178,2,82,4,2,14,613,8,38,145,83,132,34,429,222,48,6,7,73,13,8,104,92,176,297,8,32,130,34,400,212,156,20,5,35,19,169,181,39,364,53,146,562,728,523,144,49,104,33,802,128,279,222,12,2,7,81,84,131,3,41,49,198,30,14,10,299,392,142,69,133,148,29,140,31,219,71,92,66,48,11,18,2,133,20,12,13,38,28,55,72,130,270,22,259,46,558,363,38,555,56,42,103,354,17,20,188,18,127,56,40,14,153,38,8,8,189,118,27,2,17,33,73,63,65,48,190,92,9,52,349,136,145,99,7,55,25,36,40,333,146,189,10,125,15,72,24,62,124,19,6,9,20,14,7],"type":"bar"},{"x":["convolution","inference","variational","statistical","spectrally","generative ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4549,), (4549, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.34567901234567905);'>Combining</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resolutions</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.33928571428571425);'>representations</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>Geographic</span> <span style=''>object</span> <span style=''>based</span> <span style=''>image</span> <span style=''>analysis</span> <span style=''>(GEOBIA)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>has</span> <span style=''>gained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>interest</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Following</span> <span style=''>this</span> <span style=''>popular</span> <span style=''>paradigm</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiscale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>operating</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3358490566037735);'>representation</span> <span style=''>built</span> <span style=''>from</span> <span style=''>two</span> <span style=''>images</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.33875338753387535);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resolutions</span> <span style=''>They</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>same</span> <span style=''>scene</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.33875338753387535);'>different</span> <span style=''>sensors</span> <span style=''>and</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>fused</span> <span style=''>together</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3358490566037735);'>representation</span> <span style=''>where</span> <span style=''>coarser</span> <span style=''>levels</span> <span style=''>are</span> <span style=''>built</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Low</span> <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6025641025641026);'>Resolution</span> <span style=''>(LSR)</span> <span style=''>or</span> <span style=''>Medium</span> <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6025641025641026);'>Resolution</span> <span style=''>(MSR)</span> <span style=''>image</span> <span style=''>while</span> <span style=''>finer</span> <span style=''>levels</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>generated</span> <span style=''>from</span> <span style=''>a</span> <span style=''>High</span> <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6025641025641026);'>Resolution</span> <span style=''>(HSR)</span> <span style=''>or</span> <span style=''>Very</span> <span style=''>High</span> <span style=''>Spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6025641025641026);'>Resolut ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Problems</span> <span style=''>with</span> <span style=''>Non</span> <span style=''>smooth</span> <span style=''>Penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>andor</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>(or</span> <span style=''>penalization)</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>control</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>induce</span> <span style=''>desired</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>Each</span> <span style=''>penalty</span> <span style=''>has</span> <span style=''>a</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates</span> <span style=''>how</span> <span style=''>strongly</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>that</span> <span style=''>penalty</span> <span style=''>should</span> <span style=''>be</span> <span style=''>enforced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Typically</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>chosen</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>error</span> <span style=''>on</span> <span style=''>a</span> <span style=''>separate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>set</span> <span style=''>using</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>grid</span> <span style=''>search</span> <span style=''>or</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>It</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>to</span> <span style=''>tune</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>if</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>but</span> <span style=''>this</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>many</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Filtering</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Smoothing</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4754098360655737);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>robust</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3316953316953316);'>stochastic</span> <span style=''>dynamic</span> <span style=''>systems</span> <span style=''>when</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>function</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>function</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.6086956521739131);'>parametric</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>GPs</span> <span style=''>are</span> <span style=''>gaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>in</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.42720763723150357);'>processing</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>robotics</span> <span style=''>and</span> <span style=''>control</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3402061855670103);'>representing</span> <span style=''>unknown</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.7204301075268817);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.30666666666666664);'>distributions</span> <span style=''>This</span> <span style=''>modern</span> <span style=''>way</span> <span style=''>of</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>is</span> <span style=''>more</span> <span style=''>robust</span> <span style=''>than</span> <span style=''>finding</span> <span style=''>point</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6086956521739131);'>parametric</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3358490566037735);'>representation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4754098360655737);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>robust</span> <span style=''>analytic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>in</span> <span style=''>GP</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Walkback</span> <span style=''>Learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transition</span> <span style=''>Operator</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Net</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>to</span> <span style=''>directly</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>operator</span> <span style=''>whose</span> <span style=''>repeated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>provides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indirectly</span> <span style=''>by</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>model</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>obeys</span> <span style=''>detailed</span> <span style=''>balance</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>energy</span> <span style=''>function</span> <span style=''>The</span> <span style=''>energy</span> <span style=''>function</span> <span style=''>is</span> <span style=''>then</span> <span style=''>modified</span> <span style=''>so</span> <span style=''>the</span> <span style=''>model</span> <span style=''>and</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>match</span> <span style=''>with</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>required</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>Moreover</span> <span style=''>the</span> <span style=''>detailed</span> <span style=''>balance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictive</span> <span style=''>energy</span> <span style=''>based</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>must</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>weights</span> <span style=''>unlike</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style=''>neural</span> <span style=''>circuits</span> <span style=''>In</span> <span style=''>c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10651941574634842)
# 	segmentation (0.06733167082294264)
# 	architecture (0.0819380121125757)
# 	knowledge (0.12931955824723904)
# 	experimental (0.14250089063056645)
# 	information (0.2593516209476309)
# 	detection (0.12468827930174564)
# 	different (0.26398289989312435)
# 	recognition (0.12967581047381546)
# 	convolutional (0.13359458496615603)
#
# Some Statistics words are:
# 	statistical (0.1440040140491721)
# 	algorithms (0.28650275965880584)
# 	stochastic (0.1359759157049674)
# 	theoretical (0.14500752634219768)
# 	variables (0.15002508780732565)
# 	distribution (0.1816357250376317)
# 	inference (0.18414450577019567)
# 	algorithm (0.39739086803813345)
# 	dimensional (0.1816357250376317)
# 	regression (0.17210235825388862)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="254c30c3-c1c4-4ff2-9689-e25d3e173efd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("254c30c3-c1c4-4ff2-9689-e25d3e173efd")) {                    Plotly.newPlot(                        "254c30c3-c1c4-4ff2-9689-e25d3e173efd",                        [{"x":["convolution","inference","variational","statistical","spectrally","generative","stationary","equivalent","contributions","dynamical","generated","synthetic","nonparametric","demonstrated","construction","inferential","phenomena","modelling","significantly","determining","asymptotic","reduction","criterion","principled","description","different","properties","dimension","observation","reasonable","suitability","underlying","examining","neuroimaging","empirical","numerical","clustering","compression","minimizes","hierarchical","structure","estimated","dimensionality","determine","dependency","furthermore","collaborate","researchers","visibility","reproducibility","facilitates","experiments","collaboration","increases","efficiently","illustrate","combination","interface","approaches","estimation","dimensions","histograms","analogies","estimates","histogram","visualized","generalization","structured","dimensional","optimization","permutations","intermediate","convergence","heuristics","experimental","distribution","theoretical","prototype","approximates","comparisons","randomized","comparison","probability","behaviour","recognition","character","difficult","algorithms","information","classification","improvement","capabilities","classifiers","incremental","algorithm","classifier","available","benchmark","forgetting","retrained","catastrophic","respectively","successfully","computing","marginalization","classifying","validation","presented","iteratively","hyperspectral","maximizes","processing","efficient","implementation","nonlinear","extracted","selection","dependence","therefore","independence","functions","dependent","appropriate","assumption","integrate","aggregating","interacting","traversal","extraction","specialized","manipulating","seamlessly","biological","relational","integrated","predictions","performed","computational","unstructured","particular","heterogeneous","framework","knowledge","constructing","demonstrate","consisting","facilitate","components","representation","declarative","projections","traditional","accelerated","variables","projection","approximately","massively","computation","distances","prohibitive","designated","segmentation","especially","commercial","commercially","implicitly","sometimes","considering","requirements","represents","addressed","developed","continuous","nonconvex","minimization","important","stochastic","practical","additional","machinery","increasingly","corresponds","regularized","minimizing","introduce","solutions","extensive","randomness","programming","inefficient","implement","iterations","heuristic","associated","paradigms","optimizations","comparatively","experiences","exploitation","providers","outperformed","posterior","recommend","variability","recommendation","decomposition","personalized","preference","viewpoints","distributed","efficiencies","estimator","subscriber","predicted","evaluated","contextual","targeting","diversity","serendipity","uncertainties","forecasts","exceptional","coefficients","diversified","identifying","uncertainty","successful","conditional","efficiency","exploration","frequency","suffering","conducted","challenge","retrieval","representative","effectiveness","robustness","crowdsourcing","attention","similarity","correlation","management","incomplete","inaccurate","applications","incorporating","inhomogeneous","annotation","explosive","assignment","simultaneously","construct","annotated","hypotheses","aniso ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	endmember
# 	propensity
# 	integrations
# 	truncation
# 	debiasing
# 	reconstructive
# 	personalizing
# 	frequentist
# 	nutrition
# 	marginalized
# 	distributionally
# 	parametrically
# 	bernstein
# 	rewritten
# 	attainable
# 	layerwise
# 	laplacians
# 	centering
# 	orthogonality
# 	hypernetworks
# Some words which never appear in Statistics papers:
# 	retrained
# 	traversal
# 	declarative
# 	commercially
# 	compatibility
# 	drosophila
# 	incentives
# 	democratize
# 	positioned
# 	annotating
# 	localizing
# 	congestion
# 	integrity
# 	contradiction
# 	deductive
# 	deductively
# 	nanoscale
# 	untrained
# 	resistive
# 	deliberately

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0656979061283305e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
